# %%
import pandas as pd

# %%
nepremicnine = pd.read_csv('podatki/nepremicnine.csv')

del nepremicnine['posred']
nepremicnine.columns = ['ime', 'vrsta', 'opis', 'leto_izgradnje', 'zemljisce', 'velikost', 'cena', 'agencija', 'regija']

# %%
nepremicnine
# Out:
#                                             ime             vrsta  \
# 0      BIZOVIK, OB LITISIJSKI, 2 PARKIRNI MESTI        Stanovanje
# 1                                          BRDO              Hiša
# 2                    ČRNUČE, BRNČIČEVA ULICA 31  Poslovni prostor
# 3         DRAVELJSKA GMAJNA, KAMNOGORIŠKA CESTA        Stanovanje
# 4           GALJEVICA, NA VOLJO LE ŠE ENA ENOTA              Hiša
# ...                                         ...               ...
# 13183                                   ŽIBERCI            Posest
# 13184                                  ŽITKOVCI              Hiša
# 13185                                  ŽITKOVCI              Hiša
# 13186                                     ŽIŽKI              Hiša
# 13187                                 ŽIŽKI, 52  Poslovni prostor
#
#                      opis  leto_izgradnje  zemljisce  velikost      cena  \
# 0           triinpolsobno            2008        NaN     79.90  210000.0
# ...
